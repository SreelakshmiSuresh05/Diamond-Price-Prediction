# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
a=df['cut'].value_counts()
a
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
cut=a.index
count=a.values
plt.pie(count,labels=cut,autopct='%1.01f%%')
plt.legend(title='Cut',loc='upper right')
plt.title(" CUT vs COUNT")
plt.show()

# %%
b=df['color'].value_counts()
b
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
cut=b.index
count=b.values
plt.plot(cut,count,marker='o',mfc='hotpink',mec='r',label='color')
plt.title(" Colour vs Value Count ")
plt.show()

# %%
df.value_counts(df['clarity'])
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
sns.countplot(x='clarity',data=df,color='pink')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
sns.boxplot(x='carat',y='cut',data=df)
# Out:
# <Axes: xlabel='carat', ylabel='cut'>

# %%
cl = ['carat','depth','table','price','x','y','z']
for i in cl:
  sns.pairplot(data=df)
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.pairplot(data=df,corner=True,palette='pastel',hue='cut')
plt.show()

# %% [markdown]
# Removing outliers

# %%
numeric_cols = ['carat','depth','table','price','x','y','z']

# Loop over each column and remove outliers
for col in numeric_cols:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    # Calculate the IQR
    IQR = Q3 - Q1

    # Define the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter the DataFrame to remove outliers
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print(df)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# Encoding done by using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
lst = ["cut","color","clarity"]
for i in lst:
  df[i] = enc.fit_transform(df[i])

# %%
df
# Out:
#        Unnamed: 0  carat  cut  color  clarity  depth  table  price     x  \
# 0               1   0.23    2      1        3   61.5   55.0    326  3.95
# 1               2   0.21    3      1        2   59.8   61.0    326  3.89
# 3               4   0.29    3      5        5   62.4   58.0    334  4.20
# 4               5   0.31    1      6        3   63.3   58.0    335  4.34
# 5               6   0.24    4      6        7   62.8   57.0    336  3.94
# ...           ...    ...  ...    ...      ...    ...    ...    ...   ...
# 53935       53936   0.72    2      0        2   60.8   57.0   2757  5.75
# 53936       53937   0.72    1      0        2   63.1   55.0   2757  5.69
# 53937       53938   0.70    4      0        2   62.8   60.0   2757  5.66
# 53938       53939   0.86    3      4        3   61.0   58.0   2757  6.15
# 53939       53940   0.75    2      0        3   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 3      4.23  2.63
# ...

# %%
x = df.drop("price",axis=1)
y = df["price"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#        Unnamed: 0  carat  cut  color  clarity  depth  table     x     y     z
# 2596         2597   0.52    2      0        6   62.0   57.0  5.15  5.17  3.20
# 4934         4935   0.91    1      0        2   64.0   58.0  6.09  6.06  3.89
# 4645         4646   0.91    3      5        4   61.9   57.0  6.24  6.19  3.85
# 44812       44813   0.50    2      1        5   62.2   55.0  5.07  5.09  3.16
# 32262       32263   0.36    2      2        4   61.9   56.0  4.56  4.59  2.83
# ...           ...    ...  ...    ...      ...    ...    ...   ...   ...   ...
# 12377       12378   0.26    1      1        1   59.6   61.0  4.13  4.16  2.47
# 51990       51991   0.56    2      3        1   61.8   56.0  5.28  5.34  3.28
# 44904       44905   0.55    3      1        2   62.4   57.6  5.23  5.28  3.27
# 956           957   0.80    2      2        2   62.4   57.0  5.90  5.87  3.67
# 17220       17221   1.21    2      1        2   62.0   56.0  6.83  6.76  4.21
#
# [32572 rows x 10 columns]

# %%
y_train
# Out:
# 2596     3218
# 4934     3730
# 4645     3669
# 44812    1624
# 32262     789
#          ...
# 12377     597
# 51990    2442
# 44904    1630
# 956      2890
# 17220    6887
# Name: price, Length: 32572, dtype: int64

# %%
x_test
# Out:
#        Unnamed: 0  carat  cut  color  clarity  depth  table     x     y     z
# 3627         3628   0.90    3      5        5   62.4   60.0  6.16  6.06  3.81
# 30713       30714   0.33    2      1        5   61.5   55.0  4.47  4.50  2.76
# 3555         3556   0.74    4      1        4   62.8   59.0  5.68  5.76  3.59
# 39451       39452   0.50    1      1        3   63.7   55.0  5.03  5.08  3.22
# 48559       48560   0.71    2      1        3   62.6   55.0  5.72  5.68  3.57
# ...           ...    ...  ...    ...      ...    ...    ...   ...   ...   ...
# 38709       38710   0.42    4      4        6   63.9   56.0  4.73  4.75  3.03
# 35405       35406   0.32    2      1        5   61.9   56.0  4.40  4.36  2.71
# 43841       43842   0.52    2      2        5   61.6   56.0  5.14  5.18  3.18
# 14285       14286   1.06    3      4        5   62.0   58.0  6.50  6.57  4.05
# 16808       16809   1.05    1      4        1   64.3   58.0  6.50  6.35  4.13
#
# [13960 rows x 10 columns]

# %%
y_test
# Out:
# 3627     3431
# 30713     738
# 3555     3416
# 39451    1077
# 48559    1991
#          ...
# 38709    1042
# 35405     900
# 43841    1446
# 14285    5783
# 16808    6703
# Name: price, Length: 13960, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error
print("R2 SCORE:",r2_score(y_test,y_pred))
print("MEAN ABSOLUTE ERROR:",mean_absolute_error(y_test,y_pred))
print("MEAN ABSOLUTE PERCENTGAE ERROR:",mean_absolute_percentage_error(y_test,y_pred))
k=mean_squared_error(y_test,y_pred)
print("MEAN SQUARED ERROR:",k)
print("ROOT MEAN SQUARED ERROR:",np.sqrt(k))
# Out:
# R2 SCORE: 0.8920435088957359
# MEAN ABSOLUTE ERROR: 574.6603316811718
# MEAN ABSOLUTE PERCENTGAE ERROR: 0.28417493228841917
# MEAN SQUARED ERROR: 731587.8990506096
# ROOT MEAN SQUARED ERROR: 855.3291173873421

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print("R2 SCORE:",r2_score(y_test,y_pred))
print("MEAN ABSOLUTE ERROR:",mean_absolute_error(y_test,y_pred))
print("MEAN ABSOLUTE PERCENTGAE ERROR:",mean_absolute_percentage_error(y_test,y_pred))
k=mean_squared_error(y_test,y_pred)
print("MEAN SQUARED ERROR:",k)
print("ROOT MEAN SQUARED ERROR:",np.sqrt(k))
# Out:
# R2 SCORE: 0.9998491927367189
# MEAN ABSOLUTE ERROR: 3.5270078796561677
# MEAN ABSOLUTE PERCENTGAE ERROR: 0.004865683054171571
# MEAN SQUARED ERROR: 1021.9743878008595
# ROOT MEAN SQUARED ERROR: 31.96833414178567
